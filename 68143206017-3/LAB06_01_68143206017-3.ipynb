# %%
#START
#   IMPORT RANDOM
#   ANSWER = RANDOM.RADINT(1,100)
#

# %%
import random
try:
    answer = random.randint(1,100)
    print("ยินดีต้อนรับเข้าสู่เกมทายเลข ของฉัน")
    print("ตอนนี้ฉันได้สุ่มตัวเลขมาหนึ่งตัวระหว่าง 1 ถึง 100 แล้ว นายลองทายดูสิ!")

    count = 0
    while True:
        #รับค่าจากผู้เล่นแล้วแปลงเป็น int      
        guess = int(input("กรุณาป้อนตัวเลขที่คุณต้องการทาย"))
        count += 1
        if guess == answer:
            print("ยินดีด้วยคุณทายถูกต้อง ✅😍🎉")
            print("คุณทายไปทั้งหมด",count,"ครั้ง")
            break
        elif guess < answer:
            print("❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐")
        else:
            print("❎คุณทายเลข สูง ไปนะ ลองทายดูอีกครั้ง🧐")
except ValueError :
    print("ข้มูลไม่ถูกต้อง")
# Out:
# ยินดีต้อนรับเข้าสู่เกมทายเลข ของฉัน
# ตอนนี้ฉันได้สุ่มตัวเลขมาหนึ่งตัวระหว่าง 1 ถึง 100 แล้ว นายลองทายดูสิ!
# ❎คุณทายเลข สูง ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ❎คุณทายเลข ต่ำ ไปนะ ลองทายดูอีกครั้ง🧐
# ยินดีด้วยคุณทายถูกต้อง ✅😍🎉
# ...
